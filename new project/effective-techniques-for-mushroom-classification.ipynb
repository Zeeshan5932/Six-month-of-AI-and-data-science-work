# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; text-align:center; border-radius:0%;"> Mushroom 🍄 Dataset Analysis and Classification 📊</p>

# %% [markdown]
# ![_06f4da17-caf1-4282-8545-a61bd8d3d3b0.jpeg](attachment:0b36378f-551b-47fd-bcc4-426c4f483498.jpeg)

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; text-align:center; border-radius:0%;">About Me 🌟</p>

# %% [markdown]
# <div style='border: 4px solid none; background-color:#00BFFF; padding:20px;'>
#     <div style="float: right; margin-left: 50px;">
#         <img src="https://media.licdn.com/dms/image/D4D03AQEho5bPVChHpA/profile-displayphoto-shrink_800_800/0/1712892057663?e=1721865600&v=beta&t=rMB5UOlXPtXLEDBJZ9kHFKZAGe5-UwB5L9g_a5vFHfc" alt="Your Image" width="300px" style="border: 10px solid #E6E6FA; box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.1);">
#     </div>
#     <p style="font-family: Century Gothic; font-size: 18px; color : #E6E6FA;">
#         😁 Hi Friends! 👋
#         <br><br>
#         My name is <b>Muhammad Abdullah</b>.
#         <br> I am proficient in <b>Python</b>, <b>Data Science</b>, and <b>machine learning</b>, a student of <b>artificial intelligence</b>, and currently learning and working on <b>Plotting</b> projects.
#         <br><br>
#         Let's connect!
#         <br><br>
#         <a href="https://www.linkedin.com/in/muhammad-abdullah-6b84b4297/" target="_blank" style="color: #E6E6FA; text-decoration: none;">LinkedIn</a>
#         <br>
#         <a href="https://github.com/muhammadabdullah0303" target="_blank" style="color: #E6E6FA; text-decoration: none;">GitHub</a>
#     </p>
# </div>

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; font-family:Pacifico; text-align:center; border-radius:0%;">🍄 About Dataset 📊</p>

# %% [markdown]
# <div style='border: 3px solid none; background-color: #00BFFF ;padding:20px;'>
#     <h1 style ='color : #E6E6FA ; font-weight: bold'>Dataset Overview</h1>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         This dataset is a cleaned version of the original Mushroom Dataset for Binary Classification available at UCI Library.
#         <br><br>
#         It has undergone various cleaning techniques such as modal imputation, one-hot encoding, z-score normalization, and feature selection.
#         <br><br>
#         It contains 9 columns:
#         <br><br>
#         🍄 Cap Diameter
#         <br>
#         🍄 Cap Shape
#         <br>
#         🍄 Gill Attachment
#         <br>
#         🍄 Gill Color
#         <br>
#         🍄 Stem Height
#         <br>
#         🍄 Stem Width
#         <br>
#         🍄 Stem Color
#         <br>
#         🍄 Season
#         <br>
#         🍄 Target Class - Is it edible or not?
#         <br><br>
#         The Target Class contains two values - 0 or 1 - where 0 refers to edible and 1 refers to poisonous.
#     </p>
# </div>

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; text-align:center; border-radius:0%;"> Basic Utilization 🛠️</p>

# %%
# %pip install lightgbm==4.3.0
# Out:
# ...
#   Using cached lightgbm-4.3.0-py3-none-win_amd64.whl.metadata (19 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\zeesh\\miniconda3\\envs\\python_ml\\lib\\site-packages\\scipy-1.12.0.dist-info\\METADATA'

# %%
# Import Libraires
import numpy as np
import seaborn as sns 
import pandas as pd
import math
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import termcolor2
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, LabelEncoder
from sklearn.model_selection import cross_val_score, KFold
from colorama import Fore, Style, init;
# Import necessary libraries
from IPython.display import display, HTML
from matplotlib.colors import LinearSegmentedColormap
import warnings
warnings.filterwarnings('ignore')
print_unique_header("Setup Intiltized")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 24
#      22 import warnings
#      23 warnings.filterwarnings('ignore')
# ---> 24 print_unique_header("Setup Intiltized")
#
# NameError: name 'print_unique_header' is not defined

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; text-align:center; border-radius:0%;"> Load and Overview Data 📊</p>

# %% [markdown]
# <div style='border: 3px solid none; background-color: #00BFFF ;padding:20px;'>
#     <h1 style ='color : #E6E6FA ; font-weight: bold'>📊 Data Loading and Initialization 📊</h1>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>1. Load Data:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         The Mushroom dataset is loaded from a CSV file located at '/kaggle/input/mushroom-dataset/mushroom_cleaned.csv'. 🍄
#     </p>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>2. Initialize the Class by Passing Data:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         An instance of the `Plotting_by_Abdullah` class is initialized by passing the loaded Mushroom dataset. This class seems to be designed for plotting and visualizing data. 🎨
#     </p>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>3. Overview:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         The `D_O` function is called to provide an overview of the Mushroom dataset. This function likely displays basic statistics or information about the dataset. 📝
#     </p>
# </div>

# %%
# Then We Call Our Main Class and Pass The Data , as we intilize above 
# 1. We Can Direct Load The Data or We Can Load The Data first and Pass The Varivale as i mention Below
# Load Data 
Mushroom = pd.read_csv('/kaggle/input/mushroom-dataset/mushroom_cleaned.csv')

# Intlize The Class By Passing Data
# plt_Abd = Plotting_by_Abdullah(DATA=sns.load_dataset('iris'))
plt_Abd = Plotting_by_Abdullah(Mushroom)

# Over View 
D_O(Mushroom)
# Out:
# ╭─────────────────────────────────────────────────╮
# │          ▲
# │          The Head Of Train Dataset is:          │
# │          ▼
# ╰─────────────────────────────────────────────────╯
# <table style="border: 2px solid #00BFFF;">
#   <thead>
#     <tr style="text-align: right;">
#       <th>cap-diameter</th>
#       <th>cap-shape</th>
#       <th>gill-attachment</th>
#       <th>gill-color</th>
#       <th>stem-height</th>
#       <th>stem-width</th>
#       <th>stem-color</th>
#       <th>season</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="color: #E6E6FA;">1372</td>
#       <td style="color: #E6E6FA;">2</td>
#       <td style="color: #E6E6FA;">2</td>
#       <td style="color: #E6E6FA;">10</td>
#       <td style="color: #E6E6FA;">3.807467</td>
#       <td style="color: #E6E6FA;">1545</td>
#       <td style="color: #E6E6FA;">11</td>
#       <td style="color: #E6E6FA;">1.804273</td>
#       <td style="color: #E6E6FA;">1</td>
# ...

# %%
# Drop Duplicates 
Mushroom.drop_duplicates(inplace=True)

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; text-align:center; border-radius:0%;">Basic Exploratory Data Analysis (EDA) 📊</p>

# %% [markdown]
# <div style='border: 3px solid none; background-color: #00BFFF ;padding:20px;'>
#     <h1 style ='color : #E6E6FA ; font-weight: bold'>Code Explanation (Edited by ChatGPT) :</h1>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>1. 🎨 Relationship of Independent Variables With Target Variable 📊</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         In this section, scatter plots are generated to visualize the relationship between independent variables and the target variable.
#         <br><br>
#         🔍 `scatter_plot_small('stem-width', hue='class', palette=custom_palette)`: A scatter plot is created with 'stem-width' as the independent variable and 'class' as the target variable. Each class is represented with a different color specified by the custom palette.
#     </p>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>2. 🎻 Class Wise Relation of Each-Variable 📈</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         This section presents violin plots to depict the distribution of each variable across different classes.
#         <br><br>
#         🎻 `violin_plot('class', palette=custom_palette)`: Violin plots are generated to show the distribution of each variable with respect to the target variable ('class'). Custom colors from the palette are used for better visualization.
#     </p>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>3. 📊 Feature Distribution 📈</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         Here, histograms are plotted to provide a quick overview of the distribution of features in the dataset.
#         <br><br>
#         📊 `only_HIST(Mushroom.columns.tolist())`: Histograms for each feature in the dataset are displayed to visualize their distribution.
#     </p>
#     <h2 style ='color : #E6E6FA ; font-weight: bold'>4. 📦 Outlier Detection 🚨</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA ">
#         Lastly, box plots are utilized to detect outliers in the dataset.
#         <br><br>
#         📦 `only_BOX()`: Box plots are generated for each feature to identify potential outliers.
#     </p>
# </div>

# %%
# Now we Call The Variale Class and Call The Scatter Plot Function With Custom Paramter Hue
print_boxed_zigzag_heading('Relationship of Independent Variables With Target Variable')
# plt_Abd.scatter_plot_small('stem-height',hue ='class',palette=custom_palette)
plt_Abd.scatter_plot_small('stem-width', hue='class', palette=custom_palette)

# Now we Call The Variale Class and Call The Voilin Plot Function With Custom Paramters
print_boxed_zigzag_heading('Class Wise Relation of Each-Variable')
plt_Abd.violin_plot('class',palette=custom_palette)

# Now we Call The Variale Class and Call The Quick Overview Function With Custom Paramters
print_boxed_zigzag_heading('Feature Distribution')
plt_Abd.only_HIST(Mushroom.columns.tolist())
print_boxed_zigzag_heading('Outlier Dedection')
plt_Abd.only_BOX()
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────╮
# │ Relationship │ of │ Independent │ Variables │ With │ Target │ Variable │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────────────╮
# │ Class │ Wise │ Relation │ of │ Each-Variable │
# ╰────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────╮
# │ Feature │ Distribution │
# ╰────────────────────────────────────────╯
# ╭─────────────────────────────────────╮
# │ Outlier │ Dedection │
# ╰─────────────────────────────────────╯

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; text-align:center; border-radius:0%;">Machine Learning Modeling 🤖</p>

# %% [markdown]
# <div style='border: 3px solid none; background-color: #00BFFF; padding:20px;'>
#     <h1 style ='color : #E6E6FA; font-weight: bold'>🔍 Code Explanation 🔍</h1>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>1. Initialize the Class:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         An instance of the `Abdullah_Auto_Ml` class is created, presumably for automating machine learning tasks. It seems to take a dataset named `Mushroom` as input. 🏗️
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>2. Scale Data:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         The data is scaled using the `apply_scaling` method of the `auto_ml` object. It scales the specified columns, including 'cap-diameter', 'stem-width', and 'season', using a scaler type specified as 'M'. 📏
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>3. Encode Data:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         There's a commented-out line for encoding data using the `E_D` method of the `auto_ml` object. It encodes the scaled data using the specified method. However, this line is currently inactive. 🗒️
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>4. Split X and y:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         The data is split into features (X) and the target variable (y) using the `Split_X_y` method of the `auto_ml` object. It seems to split the scaled data, with the target variable specified as 'class'. 🎯
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>5. Train Test Split:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         The data is further split into training and validation sets using the `Train_Test` method of the `auto_ml` object. It splits the features and target variable into training and validation sets with a 90:10 ratio. 🚂🛤️
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>6. Train Auto ML Random Forest Classifier:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         The Random Forest Classifier is trained using the `Train_ML` method of the `auto_ml` object. It trains the classifier for a specified number of iterations (5) using the training data and evaluates its performance on the validation data. 🌲
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>7. Train Auto ML Decision Tree Classifier:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         Similar to the previous step, the Decision Tree Classifier is trained and evaluated using the same method. 🌳
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>8. Train Auto ML LGBM Classifier:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         The LightGBM Classifier is trained and evaluated using the same method as above. 🌟
#     </p>
#     <h2 style ='color : #E6E6FA; font-weight: bold'>9. Train Auto ML CatBoost Classifier:</h2>
#     <p style="font-family: Century Gothic; font-size: 18px;color : #E6E6FA;">
#         Finally, the CatBoost Classifier is trained and evaluated using the same method as above. 🐱🚀
#     </p>
# </div>

# %%
# Intitlize The Class
auto_ml = Abdullah_Auto_Ml(Mushroom)

# Scale Data
SC_D = auto_ml.apply_scaling(['cap-diameter', 'stem-width', 'season',], scaler_type='M')

# Encode data
# En_D = auto_ml.E_D(Scaled_D=SC_D, columns=['Species'], method='L')

# Split X and y
X, y = auto_ml.Split_X_y('scaled',Target='class')

# Train Test 
X_TR, X_VAL, Y_TR, Y_VAL = auto_ml.Train_Test(X,y,10)

# Train Auto ML RF
print_unique_header("Random Forest Classifier")
auto_ml.Train_ML(RandomForestClassifier(random_state=42),
                 'Classification',5,X_TR,
                 X_VAL,Y_TR,Y_VAL)

print_unique_header("DecisionTree Classifier")
# Train Auto ML Decision Tree
auto_ml.Train_ML(DecisionTreeClassifier(random_state=42),
                 'Classification',5 ,X_TR,
                 X_VAL, Y_TR, Y_VAL)

print_unique_header("LGBM Classifier")
# Train Auto ML LGBM
auto_ml.Train_ML(lgb.LGBMClassifier(random_state=42,verbose=-1),
                 'Classification',5 ,X_TR,
                 X_VAL, Y_TR, Y_VAL)

print_unique_header("CatBoost Classifier")
# Train Auto ML
auto_ml.Train_ML(CatBoostClassifier(learning_rate=0.1, verbose=0,iterations=100),
                 'Classification',5 ,X_TR,
                 X_VAL, Y_TR, Y_VAL)
# Out:
# ╭───────────────────────────────╮
# │          ▲
# │          Data Loaded          │
# │          ▼
# ╰───────────────────────────────╯
#
# ╭────────────────────────────────╮
# │ Head │ Of │ Data │
# ╰────────────────────────────────╯
# <table style="border: 2px solid #00BFFF;">
#   <thead>
#     <tr style="text-align: right;">
#       <th>cap-diameter</th>
#       <th>cap-shape</th>
#       <th>gill-attachment</th>
#       <th>gill-color</th>
#       <th>stem-height</th>
#       <th>stem-width</th>
#       <th>stem-color</th>
#       <th>season</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="color: #E6E6FA;">1372</td>
#       <td style="color: #E6E6FA;">2</td>
#       <td style="color: #E6E6FA;">2</td>
#       <td style="color: #E6E6FA;">10</td>
#       <td style="color: #E6E6FA;">3.807467</td>
#       <td style="color: #E6E6FA;">1545</td>
#       <td style="color: #E6E6FA;">11</td>
#       <td style="color: #E6E6FA;">1.804273</td>
# ...

# %% [markdown]
# <a id="Import"></a>
# # <p style="background-color: #00BFFF; font-family:Pacifico; color:#E6E6FA; font-size:200%; font-family:Pacifico; text-align:center; border-radius:0%;">The End 🎉</p>
