# %% [markdown]
# PS4E6📊EDA + ML Model🚀
# <h1 style="font-family: Arial, sans-serif; font-size: 40px; color: charcoal gray ; font-weight: bold; font-style: italic; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); line-height: 1.2; padding: 20px; background-color: #FFF9C4; border: 4px solid purple; border-radius: 10px;">
#    PS4E6📊EDA + ML Model🚀<span style="color:red ; font-size: 40px;"></span>
# </h1>

# %% [markdown]
# <div style="box-shadow: 5px 5px 10px rgba(0, 0, 0, 0.1); border: 2px solid #3498DB; border-radius: 10px; padding: 20px; text-align: center;">
#
# <h3 style="color:#D35400; font-weight:bold;">ABOUT THE AUTHOR</h3>
#
# I am <mark>Zeeshan Younas</mark>, a passionate data scientist dedicated to mastering machine learning techniques and continually expanding my knowledge base. I believe in #KeepLearning and #KeepSupporting to keep growing and helping others in the field! 🌟.
#
# <img src="https://media.licdn.com/dms/image/D4D03AQG5iDKRRJFsCQ/profile-displayphoto-shrink_200_200/0/1714460771099?e=1727308800&v=beta&t=Flq2L6_nN0zgGW03uiWWrUchg5H6Yl56YbiEJFVZZj8" alt="Profile Picture" style="width: 200px; height: 200px; border-radius: 60%; margin:100px ;">
#
# You can find more about me on my [GitHub](https://github.com/Zeeshan5932/project) and [LinkedIn](https://www.linkedin.com/in/zeeshan-younas-919a09253/).
#
# Feel free to connect and reach out for any collaboration or queries!
#
# </div>

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:80px;text-align:center;color:#f20c0f;">Overview</p>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Dataset Description</title>
#     <style>
#         .highlight {
#             color: orange;
#             font-weight: bold;
#         }
#     </style>
# </head>
# <body>
#     <h2 style="text-align:center;color:#D35400">Dataset Description</h2>
#     <p>This dataset contains information on students, their educational background, and various academic performance metrics. Each row represents a unique student and includes the following columns:</p>
#     <ul>
#         <li><span class="highlight">ID</span>: A unique identifier for each student.</li>
#         <li><span class="highlight">Marital Status</span>: The marital status of the student (e.g., single, married).</li>
#         <li><span class="highlight">Application Mode</span>: The mode through which the student applied (e.g., online, in-person).</li>
#         <li><span class="highlight">Application Order</span>: The order in which the application was received.</li>
#         <li><span class="highlight">Course</span>: The specific course or program the student is enrolled in.</li>
#         <li><span class="highlight">Daytime/Evening Attendance</span>: Indicates whether the student attends classes during the day or evening.</li>
#         <li><span class="highlight">Previous Qualification</span>: The highest qualification the student held prior to the current course.</li>
#         <li><span class="highlight">Previous Qualification (Grade)</span>: The grade obtained in the previous qualification.</li>
#         <li><span class="highlight">Nationality</span>: The nationality of the student.</li>
#         <li><span class="highlight">Mother's Qualification</span>: The highest qualification held by the student's mother.</li>
#         <li><span class="highlight">Father's Qualification</span>: The highest qualification held by the student's father.</li>
#         <li><span class="highlight">Mother's Occupation</span>: The occupation of the student's mother.</li>
#         <li><span class="highlight">Father's Occupation</span>: The occupation of the student's father.</li>
#         <li><span class="highlight">Admission Grade</span>: The grade obtained at the time of admission to the current course.</li>
#         <li><span class="highlight">Displaced</span>: Indicates if the student is displaced (e.g., due to conflict or natural disaster).</li>
#         <li><span class="highlight">Educational Special Needs</span>: Indicates if the student has any special educational needs.</li>
#         <li><span class="highlight">Debtor</span>: Indicates if the student has any outstanding debts to the institution.</li>
#         <li><span class="highlight">Tuition Fees Up-to-Date</span>: Indicates if the student's tuition fees are paid up-to-date.</li>
#         <li><span class="highlight">Gender</span>: The gender of the student.</li>
#         <li><span class="highlight">Scholarship Holder</span>: Indicates if the student is a scholarship holder.</li>
#         <li><span class="highlight">Age at Enrollment</span>: The age of the student at the time of enrollment.</li>
#         <li><span class="highlight">Curricular Units 1st Sem (Enrolled)</span>: The number of curricular units the student enrolled in during the first semester.</li>
#         <li><span class="highlight">Curricular Units 1st Sem (Evaluations)</span>: The number of curricular units evaluated in the first semester.</li>
#         <li><span class="highlight">Curricular Units 1st Sem (Approved)</span>: The number of curricular units approved in the first semester.</li>
#         <li><span class="highlight">Curricular Units 1st Sem (Grade)</span>: The grades obtained in the first semester's curricular units.</li>
#         <li><span class="highlight">Curricular Units 1st Sem (Without Evaluations)</span>: The number of curricular units without evaluations in the first semester.</li>
#         <li><span class="highlight">Curricular Units 2nd Sem (Enrolled)</span>: The number of curricular units the student enrolled in during the second semester.</li>
#         <li><span class="highlight">Curricular Units 2nd Sem (Evaluations)</span>: The number of curricular units evaluated in the second semester.</li>
#         <li><span class="highlight">Curricular Units 2nd Sem (Approved)</span>: The number of curricular units approved in the second semester.</li>
#         <li><span class="highlight">Curricular Units 2nd Sem (Grade)</span>: The grades obtained in the second semester's curricular units.</li>
#         <li><span class="highlight">Curricular Units 2nd Sem (Without Evaluations)</span>: The number of curricular units without evaluations in the second semester.</li>
#         <li><span class="highlight">Unemployment Rate</span>: The unemployment rate in the student's region.</li>
#         <li><span class="highlight">Inflation Rate</span>: The inflation rate in the student's region.</li>
#         <li><span class="highlight">GDP</span>: The Gross Domestic Product in the student's region.</li>
#         <li><span class="highlight">Target</span>: The target variable indicating the student's academic success or another outcome of interest.</li>
#     </ul>
# </body>
# </html>

# %% [markdown]
# <div style="text-align: center; background: #EF5A6F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 80% 0 90% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Module-1</div>

# %% [markdown]
#  <h2 style="text-align:center;color:#D35400">Import Libraries</h2>

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
#  <h2 style="text-align:center;color:#D35400">Load Dataset</h2>

# %%
tr = pd.read_csv('./Data/train.csv')
ts = pd.read_csv('./Data/test.csv')
sb = pd.read_csv('./Data/sample_submission.csv')

# %%
tr.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# ...

# %%
ts.head()
# Out:
#       id  Marital status  Application mode  Application order  Course  \
# 0  76518               1                 1                  1    9500
# 1  76519               1                 1                  1    9238
# 2  76520               1                 1                  1    9238
# 3  76521               1                44                  1    9147
# 4  76522               1                39                  1    9670
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                      39
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           141.0            1                       3  ...
# ...

# %%
#Drop 'id' column from train and test data
tr.drop('id', axis=1, inplace=True)
ts.drop('id', axis=1, inplace=True)

# %% [markdown]
# # Check Statistical

# %%
tr.describe()
# Out:
#        Marital status  Application mode  Application order        Course  \
# count    76518.000000      76518.000000       76518.000000  76518.000000
# mean         1.111934         16.054419           1.644410   9001.286377
# std          0.441669         16.682337           1.229645   1803.438531
# min          1.000000          1.000000           0.000000     33.000000
# 25%          1.000000          1.000000           1.000000   9119.000000
# 50%          1.000000         17.000000           1.000000   9254.000000
# 75%          1.000000         39.000000           2.000000   9670.000000
# max          6.000000         53.000000           9.000000   9991.000000
#
#        Daytime/evening attendance  Previous qualification  \
# count                76518.000000            76518.000000
# mean                     0.915314                3.658760
# std                      0.278416                8.623774
# min                      0.000000                1.000000
# ...

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  76518 non-null  int64
#  1   Application mode                                76518 non-null  int64
#  2   Application order                               76518 non-null  int64
#  3   Course                                          76518 non-null  int64
#  4   Daytime/evening attendance                      76518 non-null  int64
#  5   Previous qualification                          76518 non-null  int64
#  6   Previous qualification (grade)                  76518 non-null  float64
#  7   Nacionality                                     76518 non-null  int64
#  8   Mother's qualification                          76518 non-null  int64
# ...

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51012 entries, 0 to 51011
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  51012 non-null  int64
#  1   Application mode                                51012 non-null  int64
#  2   Application order                               51012 non-null  int64
#  3   Course                                          51012 non-null  int64
#  4   Daytime/evening attendance                      51012 non-null  int64
#  5   Previous qualification                          51012 non-null  int64
#  6   Previous qualification (grade)                  51012 non-null  float64
#  7   Nacionality                                     51012 non-null  int64
#  8   Mother's qualification                          51012 non-null  int64
# ...

# %%
# check shape of train and test data
print("\n There are {:,} rows and {} columns in the Playground Series Train Data.".format(tr.shape[0], 
                                                                           tr.shape[1]))
print("\n There are {:,} rows and {} columns in the Playground.Series Test Data ".format(ts.shape[0], 
                                                                           ts.shape[1]))
# Out:
#  There are 76,518 rows and 37 columns in the Playground Series Train Data.
#
#  There are 51,012 rows and 36 columns in the Playground.Series Test Data

# %% [markdown]
#  <h2 style="text-align:center;color:#D35400"> Data Prepeartion</h2>

# %%
print(f'Missing values in train data: {tr.isnull().sum().sum()}')
print(f'Missing values in test data: {ts.isnull().sum().sum()}')
# Out:
# Missing values in train data: 0
# Missing values in test data: 0

# %% [markdown]
# >__Note__:- I can check there is no missing values in it

# %%
# check for duplicate values
print(f'Duplicate values in train data: {tr.duplicated().sum()}')
print(f'Duplicate values in test data: {ts.duplicated().sum()}')
# Out:
# Duplicate values in train data: 0
# Duplicate values in test data: 0

# %% [markdown]
# - Therr is no duplicates value

# %% [markdown]
# <div style="text-align: center; background: #EF5A6F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 80% 0 90% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Module-2</div>

# %% [markdown]
#  <h2 style="text-align:center;color:#D35400"> Exploartary Data analysis</h2>

# %%
tr.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 1                  1    9238
# 1               1                17                  1    9238
# 2               1                17                  2    9254
# 3               1                 1                  3    9500
# 4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           126.0            1                       1
# 1                           125.0            1                      19
# ...

# %%
import plotly.graph_objects as go
# Count the occurrences of each unique value in the Target column
target_counts = tr['Target'].value_counts()

# Extract labels and values for the pie chart
labels = target_counts.index.tolist()
values = target_counts.values.tolist()

# Define colors for the pie chart
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen']

# Create the pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=20,
                  marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.update_layout(title='Target Distribution', font=dict(size=20))

# Display the pie chart
fig.show()

# %%
# numerical columns
num_cols = tr.select_dtypes(include=['int64', 'float64']).columns
print('Categorical Columns:', num_cols)
# Out:
# Categorical Columns: Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
# Distribution of numeric variables
plt.figure(figsize=(20, 15))
plotnumber = 1

for column in num_cols:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.histplot(tr[column], kde=True, color='red')
        plt.xlabel(column)
        
    plotnumber += 1

plt.suptitle('Distribution of Numeric Variables', fontsize=40, y=1)
plt.tight_layout()
plt.show()

# %%
# Make histplot
sns.set(rc={'figure.figsize': (25, 20)})
tr.hist(color='blue', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False);

# %%
# make a correlation matrix on target column
f, ax = plt.subplots(figsize=(10, 8))
corr = tr.drop(columns=['Target']).corr()
corr.style.background_gradient(cmap='coolwarm')
                                            
# plot the correlation matrix
sns.heatmap(corr, square=True, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
# Encode "Target" Varibale using label encoder

le = LabelEncoder()
tr['Target'] = le.fit_transform(tr['Target'])

# %%
tr['Target'].value_counts()
# Out:
# 2    36282
# 0    25296
# 1    14940
# Name: Target, dtype: int64

# %% [markdown]
# <div style="text-align: center; background: #EF5A6F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 80% 0 90% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Module-3</div>

# %% [markdown]
#  <h2 style="text-align:center;color:#D35400"> Model Building</h2>

# %%
X = tr.drop(columns=['Target'])
Y = tr['Target']

# %%
# Encode "Target" Varibale using label encoder

le = LabelEncoder()
tr['Target'] = le.fit_transform(tr['Target'])

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# initialize the model for classification
rd = RandomForestClassifier(n_estimators=100, random_state=42)

# fit the model
rd.fit(X_train, y_train)

# make predictions
y_pred = rd.predict(X_test)

# evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 82.66%

# %%
# import classification report

from sklearn.metrics import classification_report

# %%
# initialize the model of catboost, xgboost and lightgbm

cb = CatBoostClassifier(n_estimators=100, random_state=42)

xgb = XGBClassifier(n_estimators=100, random_state=42)

lgbm = LGBMClassifier(n_estimators=100, random_state=42)

# fit the model
cb.fit(X_train, y_train)
xgb.fit(X_train, y_train)
lgbm.fit(X_train, y_train)


# make predictions
y_pred_cb = cb.predict(X_test)
y_pred_xgb = xgb.predict(X_test)
y_pred_lgbm = lgbm.predict(X_test)

# evaluate the model
accuracy_cb = accuracy_score(y_test, y_pred_cb)
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
accuracy_lgbm = accuracy_score(y_test, y_pred_lgbm)

print("Accuracy of CatBoost: {:.2f}%".format(accuracy_cb * 100))
print("Accuracy of XGBoost: {:.2f}%".format(accuracy_xgb * 100))
print("Accuracy of LightGBM: {:.2f}%".format(accuracy_lgbm * 100))
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6973491	total: 46.4ms	remaining: 4.6s
# 1:	learn: 0.5848838	total: 100ms	remaining: 4.91s
# 2:	learn: 0.5361809	total: 146ms	remaining: 4.71s
# 3:	learn: 0.5072183	total: 183ms	remaining: 4.38s
# 4:	learn: 0.4908398	total: 213ms	remaining: 4.05s
# 5:	learn: 0.4813393	total: 250ms	remaining: 3.91s
# 6:	learn: 0.4755968	total: 285ms	remaining: 3.79s
# 7:	learn: 0.4717242	total: 330ms	remaining: 3.79s
# 8:	learn: 0.4686097	total: 369ms	remaining: 3.73s
# 9:	learn: 0.4640854	total: 413ms	remaining: 3.71s
# 10:	learn: 0.4615071	total: 461ms	remaining: 3.73s
# 11:	learn: 0.4595338	total: 499ms	remaining: 3.66s
# 12:	learn: 0.4569491	total: 533ms	remaining: 3.56s
# 13:	learn: 0.4558263	total: 562ms	remaining: 3.45s
# 14:	learn: 0.4533528	total: 599ms	remaining: 3.39s
# 15:	learn: 0.4520598	total: 631ms	remaining: 3.31s
# 16:	learn: 0.4503184	total: 666ms	remaining: 3.25s
# 17:	learn: 0.4486067	total: 699ms	remaining: 3.19s
# ...

# %%
# Check the accuracy of the best model
print("Accuracy  on test: ", Best_model.score(X_test, y_test))
print('Accuracy on train: ', Best_model.score(X_train, y_train))
# Out:
# Accuracy  on test:  0.8335729221118662
# Accuracy on train:  0.8502793478616003

# %%
# Check the accuracy of the best model
print("Accuracy of the Best Model: {:.2f}%".format(Best_model.score(X_test, y_test) * 100))
# Out:
# Accuracy of the Best Model: 83.36%

# %% [markdown]
#  <h2 style="text-align:center;color:#D35400"> Check Accuracy</h2>

# %%
ts = pd.read_csv('./Data/test.csv')

# %%
#drop 'id' column  test data
ts.drop('id', axis=1, inplace=True)
pred = Best_model.predict(ts)

# %%
label_mapping = {0: 'Dropout', 1: 'Enrolled', 2: 'Graduate'}

pred_labels = np.vectorize(label_mapping.get)(pred)

# %%
sb['Target'] = pred_labels
sb.head()
# Out:
#       id    Target
# 0  76518   Dropout
# 1  76519  Graduate
# 2  76520  Graduate
# 3  76521  Enrolled
# 4  76522  Enrolled

# %%
submission = sb.to_csv('submission.csv', index=False)
# Out:
# submission.csv file created successfully! None

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Notebook</title>
#     <style>
#         body {
#             background-color: black;
#             font-family: Arial, sans-serif;
#         }
#         .note {
#             color: yellow;
#             background-color: black;
#         }
#         .comment {
#             color: yellow;
#             background-color: black;
#         }
#     </style>
# </head>
# <body>
#     <div class="note">
#         Thank you for this. Please read my notebook and provide any suggestions. If you have any queries, please leave a comment.
#     </div>
# </body>
# </html>
