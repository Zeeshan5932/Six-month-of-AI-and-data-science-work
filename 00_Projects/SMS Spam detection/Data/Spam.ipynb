# %% [markdown]
# <a id="top"></a>
# <div style="text-align: center; background: #ff8c00; font-family: 'Montserrat', sans-serif; color: white; padding: 15px; font-size: 30px; font-weight: bold; line-height: 1; border-radius: 20px 20px 0 0; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.2);">🚀 Email Spam Detection 🚀</div>

# %% [markdown]
# ![_ac0bab43-3ec8-4039-9cad-d0fdde986c84.jpeg](attachment:_ac0bab43-3ec8-4039-9cad-d0fdde986c84.jpeg)

# %% [markdown]
# <div style="box-shadow: 5px 5px 10px pink; border: 2px solid #D35400; border-radius: 10px; padding: 20px;">
#
# <h3 style="color:#D35400; font-weight:bold;">AIMS</h3>
#
# Our aim is to get the best model with the best RMSLE score.<br>
# - First, we will conduct some basic EDA.<br>
# - Then, we will perform Pre-processing and encoding.<br>
# - Finally, we'll use some famous algorithms to get the best model.<br><br>
#
#
#
# <h3 style="color:#D35400; font-weight:bold;">ABOUT THE AUTHOR</h3>
#
# I am <b>Zeeshan Younas</b>, a passionate data scientist dedicated to mastering machine learning techniques and continually expanding my knowledge base. I believe in #KeepLearning and #KeepSupporting to keep growing and helping others in the field! 🌟.<br><br>
#
# <img src="https://media.licdn.com/dms/image/D4D03AQG5iDKRRJFsCQ/profile-displayphoto-shrink_200_200/0/1714460771099?e=1720051200&v=beta&t=v8MfJW0-fdwbuOjHePjBMSdor0Nq5PhBhrpAtXhljlk" alt="Profile Picture" style="width: 100px; height: 100px; border-radius: 50%;"><br>
# You can find more about me on my <a href="https://github.com/Zeeshan5932/project" target="_blank">GitHub</a> and <a href="https://www.linkedin.com/in/zeeshan-younas-919a09253/" target="_blank">LinkedIn</a>.<br>
# Feel free to connect and reach out for any collaboration or queries!
#
# </div>

# %% [markdown]
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">Content Table</div>

# %% [markdown]
# <div style="font-size: 14px; font-family: Verdana; border: 2px solid #ccc; background-color: #F5F5F5; padding: 10px; border-radius: 10px; margin-bottom: 20px; position: relative;">
#
#   <!-- Add the image inside the div, aligned to the right-center -->
#    <img src="https://media.giphy.com/media/2lQzj96U6fb5qbknOW/giphy.gif" style="position: absolute; left:30%; right: 0; transform: translateY(-50%); width: 200px; height: auto;">
#    <img src="https://media.giphy.com/media/2lQzj96U6fb5qbknOW/giphy.gif" style="position: absolute; left:60%; right: 0; transform: translateY(-50%); width: 200px; height: auto;">
#
#   <span style="color: #FF5733; font-weight: bold;">Steps to be Performed</span>
#   <ol>
#     <li><a href="#1">Introduction</a></li>
#     <li><a href="#2">Problem Statement 🙋</a></li>
#     <li><a href="#3">Import Libraries 🔍</a></li>
#     <li><a href="#4">Statistical Overview</a></li>
#     <li><a href="#5">Data Cleaning 🧹</a></li>
#     <li><a href="#6">Text Preprocessing ✍️</a></li>
#     <li><a href="#7">Model Building 🤖</a></li>
#     <li><a href="#7">Evaluation 📈</a></li>
#     <li><a href="#9">Conclusion 🎉</a></li>
#   </ol>
# </div>

# %% [markdown]
# <a id="1"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 80% 0 90% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">1. Introduction</div>

# %% [markdown]
# <span style="font-size: 14px; font-family: Verdana; background-color: #F5F5F5; border: 2px solid #ccc; padding: 10px; border-radius: 10px; display: inline-block;">
#   This Kaggle notebook presents a step-by-step guide to building an efficient SMS <span style="background-color: #FF5733; color: black; font-weight: bold; padding: 3px 6px; border-radius: 3px;">spam</span> classification model using the SMS Spam Collection dataset.By the end of this notebook, you'll have a reliable tool to help filter out unwanted messages, making your text messaging experience smoother and safer. 😊

# %% [markdown]
# <a id="2"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 80% 0 90% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">2. Problem Statement</div>

# %% [markdown]
# <span style="font-size: 14px; font-family: Verdana; border: 2px solid #ccc;background-color: #F5F5F5; padding: 10px; border-radius: 10px; display: inline-block; margin-bottom: 20px;">
#   The primary goal of this notebook is to develop a predictive model that accurately classifies incoming SMS messages as either <span style="background-color: #FF5733; color: black; font-weight: bold; padding: 3px 6px; border-radius: 3px;">ham</span> or <span style="background-color: #FF5733; color: white; font-weight: bold; padding: 3px 6px; border-radius: 3px;">spam</span>. We will use the SMS Spam Collection dataset, which consists of 5,574 SMS messages tagged with their respective labels.

# %% [markdown]
# <a id="3"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 80% 0 90% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">3.Import Libraries</div>

# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
# import porter stemmer
from nltk.stem import PorterStemmer
import string
# import label encoder
from sklearn.preprocessing import LabelEncoder

from bs4 import BeautifulSoup
import nltk
from wordcloud import WordCloud
# Import the necessary machine learning models from scikit-learn
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB  # Assuming you mean MultinomialNB for Naive Bayes
from sklearn.svm import SVC  # Support Vector Classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier


# Import the necessary metrics from scikit-learn
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

#CounterVectorizer Convert the text into matrics
from sklearn.feature_extraction.text import CountVectorizer



import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# drop unnecessary columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
#Rename the columns
df.rename(columns={'v1':'Category','v2':'Masseges'},inplace=True)

# %%
df.to_csv('spam mail.csv', index=False)

# %%
df.head()
# Out:
#   Category                                           Masseges
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# <a id="4"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">4. Statistical Overview🔍</div>

# %%
# Check basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Masseges  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.describe()
# Out:
#        Category                Masseges
# count      5572                    5572
# unique        2                    5169
# top         ham  Sorry, I'll call later
# freq       4825                      30

# %%
# Make bar plot on category column

cat = df['Category'].value_counts()

# Make plot  distrubution plot
plt.figure(figsize=(10,6))
sns.barplot(x=cat.index, y=cat)
plt.title("Distrubution of Category")
# Out:
# Text(0.5, 1.0, 'Distrubution of Category')

# %% [markdown]
# <a id="5"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">5. Data Cleaning</div>

# %%
# check null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Category    0
# Masseges    0
# dtype: int64

# %%
# Remove duplicates values
df.drop_duplicates(inplace=True)

# %% [markdown]
# <a id="6"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">6. Text Pre-processing</div>

# %% [markdown]
# ### Text to lower case

# %%
# Remove text to lower case 
df['Masseges'] = df['Masseges'].str.lower()

# %%
df.head()
# Out:
#    Category                                           Masseges
# 0         0  go until jurong point, crazy.. available only ...
# 1         0                      ok lar... joking wif u oni...
# 2         1  free entry in 2 a wkly comp to win fa cup fina...
# 3         0  u dun say so early hor... u c already then say...
# 4         0  nah i don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Remove punctation

# %%
# define a function to remove punctuation
df['Masseges'] = df['Masseges'].str.translate(str.maketrans('', '', string.punctuation))

# %% [markdown]
# ### Remove HTML tags

# %%
# Remove html tags
def remove_html(text):
    soup = BeautifulSoup(text, 'html.parser')
    return soup.get_text()

# Apply the function to 'Massege' Column
df['Masseges'] = df['Masseges'].apply(remove_html)

# %% [markdown]
# ### Remove Extra white space

# %%
# Remove extra white space
df['Masseges'] = df['Masseges'].str.strip()

# %% [markdown]
# ### Remove Non-Alpha Numeric Values

# %%
def remove_non_alphanumeric(text):
    return re.sub(r'[^a-zA-Z0-9]', ' ', text)


# Apply to 'Massege' Column
df['Masseges'] = df['Masseges'].apply(remove_non_alphanumeric)

# %% [markdown]
# ### Remove Special character

# %%
# Function to remove special characters
def remove_special_characters(text):
    # Replace all special characters (non-alphanumeric and non-whitespace) with an empty string
    cleaned_text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return cleaned_text

# Apply to 'Massege' Column
df['Masseges'] = df['Masseges'].apply(remove_special_characters)

# %%
# check wordcloud
text=' '.join(df['Masseges'])
wordcloud=WordCloud(width=800,height=500,background_color='white').generate(text)
plt.figure(figsize=(10,6))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Remove Stop Words

# %%
# Download NLTK stopwords corpus
nltk.download('stopwords')

# Get English stopwords from NLTK
stop_words = set(stopwords.words('english'))

# Function to remove stop words from text
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Apply remove_stopwords function to 'Text' column
df['Masseges'] = df['Masseges'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zeesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Remove Numerical values

# %%
# Function to remove numerical values from text
def remove_numerical_values(text):
    # Replace all numerical values with an empty string
    cleaned_text = re.sub(r'\d+', '', text)
    return cleaned_text


# Apply to 'Massege' Column
df['Masseges'] = df['Masseges'].apply(remove_numerical_values)

# %% [markdown]
# ### Stemming

# %%
# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Apply stemming
df['Message_stemmed'] = df['Masseges'].apply(lambda x: ' '.join([porter_stemmer.stem(word) for word in x.split()]))

# %% [markdown]
# <a id="7"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">7. Model Building</div>

# %%
# Intlize CountVectorizer
cv = CountVectorizer()

# Fitting CountVectorizer on X 
X = cv.fit_transform(df['Message_stemmed']).toarray()
y = df['Category']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
#create models
bc = BaggingClassifier(n_estimators=50, random_state=42)
gbdt = GradientBoostingClassifier(n_estimators=50, random_state=42)
xgb = XGBClassifier(n_estimators=50, random_state=42)
svc = SVC(kernel="sigmoid", gamma=1.0)
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=10)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=42)
abc = AdaBoostClassifier(n_estimators=50, random_state=42)


models = {
    'BGC': bc,
    'GBDT': gbdt,
    'xgb': xgb,
    'SVC': svc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'Adaboost': abc
}

def train_classifier(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    return accuracy, precision

# %% [markdown]
# <a id="8"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">8. Evaluation</div>

# %%
# %%time

accuracy_scores = []
precision_scores = []

# Iterate over the items in the clfs dictionary
for name, model in models.items():
    current_accuracy, current_precision = train_classifier(model, X_train, y_train, X_test, y_test)
    rounded_accuracy = round(current_accuracy, 2)
    rounded_precision = round(current_precision, 2)
    
    print()
    print("For: ", name)
    print("Accuracy: ", rounded_accuracy)
    print("Precision: ", rounded_precision)

    accuracy_scores.append(rounded_accuracy)
    precision_scores.append(rounded_precision)

# %%
# Plot the accuracy scores
plt.bar(x=['BGC', 'GBDT', 'xgb', 'SVC', 'NB', 'DT', 'LR', 'RF', 'Adaboost'], height=accuracy_scores)
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

# Plot the precision scores
plt.figure()
plt.bar(x=['BGC', 'GBDT', 'xgb', 'SVC', 'NB', 'DT', 'LR', 'RF', 'Adaboost'], height=precision_scores, color='blue')
plt.xlabel('Model')
plt.ylabel('Precision')
plt.title('Model Precision')

plt.show()

# %%
# Save the model
import pickle
pickle.dump(mnb, open('model.pkl', 'wb'))

# %% [markdown]
# <a id="9"></a>
# <div style="text-align: center; background: #FF7F7F; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 15px; font-size: 26px; font-weight: bold; line-height: 1; border-radius: 50% 0 50% 0 / 40px; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);">9. Conculsion</div>

# %% [markdown]
# <span style="font-size: 14px; font-family: Verdana; background-color: #F5F5F5; border: 2px solid #ccc; padding: 10px; border-radius: 10px; display: inline-block;">
#   <strong>Conclusion:</strong> In our evaluation of various classification algorithms, we observed the following key insights:
#
#
# - **Random Forest (RF)** stands out as the best overall model, offering high accuracy and perfect precision.
# - Models such as **Logistic Regression (LR)**, **Adaboost**, and **XGBoost (xgb)** provide strong alternatives with similar accuracy and precision metrics, making them viable choices depending on the specific needs and constraints of your application.
# - While **Naive Bayes (NB)** and **Gradient Boosting Decision Tree (GBDT)** demonstrate good performance, they may benefit from further tuning for optimal results.
# - **Bagging Classifier (BGC)** and **Decision Tree (DT)** provide moderate performance and may be suitable for less complex tasks.
# - **Support Vector Classifier (SVC)** may not be the most suitable model for the task, given its lower accuracy and precision.
#
# Ultimately, the choice of model should be guided by the specific goals and requirements of your application, such as computational efficiency, ease of use, and domain-specific considerations.
