# %% [markdown]
# <a id="top"></a>
# <div style="text-align: center; background: #ff8c00; font-family: 'Montserrat', sans-serif; color: white; padding: 15px; font-size: 30px; font-weight: bold; line-height: 1; border-radius: 20px 20px 0 0; margin-bottom: 20px; box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.2);">🚀 Deep Dive into Amazon's Stock: Trends and Insights</div>

# %% [markdown]
# <div class="author-card" style="border: 2px solid #FFA500; padding: 10px; max-width: 900px; background-color: #FFDAB9; font-family: 'Brush Script MT', cursive;  color: #333;">
#     <div style="text-align: center; margin-bottom: 10px;">
#         <img src="https://media.licdn.com/dms/image/D4D03AQG5iDKRRJFsCQ/profile-displayphoto-shrink_200_200/0/1714460771099?e=1720051200&v=beta&t=v8MfJW0-fdwbuOjHePjBMSdor0Nq5PhBhrpAtXhljlk" alt="Profile Picture" style="width: 100px; height: 100px; border-radius: 50%; border: 2px solid #FFA500; box-shadow: 0px 0px 10px 5px black;">
#     </div>
#     <h3 style="color:#FFA500; font-weight:bold; text-align: center; text-shadow: 2px 2px black ;">ABOUT THE AUTHOR</h3>
#     <p style="text-align: justify;">
#        I am <b>Zeeshan Younas</b>, a passionate data scientist dedicated to mastering machine learning techniques and continually expanding my knowledge base. I believe in #KeepLearning and #KeepSupporting to keep growing and helping others in the field! 🌟.<br><br>
#     </p>
#     <p style="text-align: center; margin-top: 10px;">
#         You can find more about me on my <a href="https://github.com/Zeeshan5932/project" target="_blank" style="color: #FFA500; text-decoration: none;">GitHub</a> and <a href="https://www.linkedin.com/in/zeeshan-younas-919a09253/" target="_blank" style="color: #FFA500; text-decoration: none;">LinkedIn</a>.<br>
#         Feel free to connect and reach out for any collaboration or queries!
#     </p>
# </div>

# %% [markdown]
#
#
#
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DD2D4A; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #FFC67D"><span style="color: red;">1</span> | Introduction ✨</p>
#
#
# <div style="border-radius: 30px 0 30px 0px; border:#FFA500 solid; padding: 15px; background-color: #06BA63; font-size:100%; text-align:left ">
#    In this project, I perform a comprehensive analysis of Amazon's stock price. I examine historical data, identify trends, and provide insights into the stock's performance over time. This analysis aims to help investors make informed decisions based on data-driven insights.
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns

# %%
df = pd.read_csv('amazone.csv')
df.head()
# Out:
#                     Datetime        Open        High         Low       Close  \
# 0  2024-04-26 09:30:00-04:00  177.679993  178.029999  177.145004  177.145004
# 1  2024-04-26 09:31:00-04:00  177.116196  177.229996  176.515198  176.770004
# 2  2024-04-26 09:32:00-04:00  176.820007  176.869995  176.244995  176.244995
# 3  2024-04-26 09:33:00-04:00  176.244995  177.190002  176.220001  176.889999
# 4  2024-04-26 09:34:00-04:00  176.910004  176.990005  176.509995  176.690002
#
#     Volume  Dividends  Stock Splits
# 0  1870782        0.0           0.0
# 1   333629        0.0           0.0
# 2   225618        0.0           0.0
# 3   231393        0.0           0.0
# 4   250578        0.0           0.0

# %%
fig = px.line(df, x='Datetime', y='Close', title='Stock Close Prices Over Time')
fig.show()

# %%
fig = px.line(df, x='Datetime', y='Open', title='Stock open Prices Over Time')

# Update the layout for background and line colors
fig.update_traces(line=dict(color=' whitesmoke'))  # Set the line color
fig.update_layout(
    plot_bgcolor='rgba(0, 0, 0, 0)',  # Set the plot background color (transparent)
    paper_bgcolor='rgba(0, 0, 0, 0)', # Set the paper background color (transparent)
    font=dict(color='white')           # Set the font color
)

# Update the overall layout for better visibility with a dark theme
fig.update_layout(
    title='Stock Open Prices Over Time',
    xaxis_title='Datetime',
    yaxis_title='Open Price',
    font=dict(
        family="Arial",
        size=12,
        color="white"
    ),
    xaxis=dict(
        showgrid=True,
        gridcolor='rgba(255, 255, 255, 0.2)',
        zerolinecolor='rgba(255, 255, 255, 0.2)'
    ),
    yaxis=dict(
        showgrid=True,
        gridcolor='rgba(255, 255, 255, 0.2)',
        zerolinecolor='rgba(255, 255, 255, 0.2)'
    )
)

fig.show()

# %%
fig = px.line(df, x='Datetime', y='High', title='Stock high Prices Over Time')

# Update the layout for background and line colors
fig.update_traces(line=dict(color='yellow'))  # Set the line color
fig.update_layout(
    plot_bgcolor='rgba(0, 0, 0, 0)',  # Set the plot background color (transparent)
    paper_bgcolor='rgba(0, 0, 0, 0)', # Set the paper background color (transparent)
    font=dict(color='white')           # Set the font color
)

# Update the overall layout for better visibility with a dark theme
fig.update_layout(
    title='Stock High Prices Over Time',
    xaxis_title='Datetime',
    yaxis_title='Open Price',
    font=dict(
        family="Arial",
        size=12,
        color="white"
    ),
    xaxis=dict(
        showgrid=True,
        gridcolor='rgba(155, 155, 155, 0.2)',
        zerolinecolor='rgba(255, 255, 255, 0.2)'
    ),
    yaxis=dict(
        showgrid=True,
        gridcolor='rgba(255, 255, 255, 0.2)',
        zerolinecolor='rgba(255, 255, 255, 0.2)'
    )
)

fig.show()

# %%
fig = px.line(df, x='Datetime', y='Low', title='Stock Low Prices Over Time')

# Update the layout for background and line colors
fig.update_traces(line=dict(color='blue'))  # Set the line color
fig.update_layout(
    plot_bgcolor='rgba(0, 0, 0, 0)',  # Set the plot background color (transparent)
    paper_bgcolor='rgba(0, 0, 0, 0)', # Set the paper background color (transparent)
    font=dict(color='white')           # Set the font color
)

# Update the overall layout for better visibility with a dark theme
fig.update_layout(
    title='Stock low Prices Over Time',
    xaxis_title='Datetime',
    yaxis_title='Open Price',
    font=dict(
        family="Arial",
        size=12,
        color="white"
    ),
    xaxis=dict(
        showgrid=True,
        gridcolor='rgba(155, 155, 155, 0.2)',
        zerolinecolor='rgba(255, 255, 255, 0.2)'
    ),
    yaxis=dict(
        showgrid=True,
        gridcolor='rgba(255, 255, 255, 0.2)',
        zerolinecolor='rgba(255, 255, 255, 0.2)'
    )
)

fig.show()

# %%
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.2, 
                    subplot_titles=('Candlestick', 'Volume'), row_width=[0.2, 0.7])

# Candlestick
fig.add_trace(go.Candlestick(x=df['Datetime'],
                             open=df['Open'],
                             high=df['High'],
                             low=df['Low'],
                             close=df['Close'],
                             name='Candlestick'), row=1, col=1)

# Volume
fig.add_trace(go.Bar(x=df['Datetime'], y=df['Volume'], name='Volume'), row=2, col=1)

fig.update_layout(title='Stock Data with Volume', xaxis_title='Date', yaxis_title='Price')
fig.show()

# %%
# Visualization 8: Rolling Mean of Closing Prices
plt.figure(figsize=(12, 6))
df['Close'].rolling(window=30).mean().plot(label='30-Day Rolling Mean', color='red')
df['Close'].plot(label='Close Price', alpha=0.5)
plt.title('30-Day Rolling Mean of Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Distrubution of volume using histogram

plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Volume', bins=20, kde=True)
plt.title('Distribution of Volume')
plt.xlabel('Volume')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style="
#   background-color: #0D0D0D;
#   color: #FFFFFF;
#   font-family: 'Roboto', sans-serif;
#   font-size: 18px;
#   padding: 10px;
#   margin: 0px 0 0 0px;
#   border-radius: 15px;
#   border: none;
#   box-shadow: 0 0 20px rgba(255, 255, 255, 0.2);
#   width: 740px;
#   text-align: left;
# ">
#   <h2 style="margin: 0;">If you find this notebook helpful please appreciate it</h2>
# </div>
