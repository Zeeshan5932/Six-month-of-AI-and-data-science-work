# %% [markdown]
# # Polynomial Regression
#
# Polynomial Regression is a form of linear regression in which the relationship between the independent variable x and dependent variable y is modeled as an nth degree polynomial. Polynomial regression fits a nonlinear relationship between the value of x and the corresponding conditional mean of y, denoted E(y |x), and has been used to describe nonlinear phenomena such as the growth rate of tissues, the distribution of carbon isotopes in lake sediments, and the progression of disease epidemics.

# %% [markdown]
# Polynomial regression ek tarah ka statistical technique hai jisme data ko fit karne ke liye polynomial equation ka istemal hota hai. Ye method tab istemal hota hai jab data points ka relationship linear nahi hota, balki curve ya non-linear hota hai. Polynomial regression mein, hum polynomial equation ka istemal karte hain jise data points ke sath fit karke, ek curve banate hain.
#
# Polynomial equation kuch is tarah hota hai:
#
# $$[Y = a_nX^n + a_{n-1}X^{n-1} + ... + a_2X^2 + a_1X + a_0]$$
#
# Yahan, $$(Y)$$ dependent variable ko represent karta hai, $$(X)$$ independent variable ko, aur $$(a_n, a_{n-1}, ... , a_0)$$ coefficients hain jo equation ko define karte hain. Degree of the polynomial $$(n)$$ hota hai, jise hum choose karte hain.
#
# Polynomial regression ka faida ye hai ke isse complex relationships ko model karne mein madad milti hai, lekin iska nuksan ye hai ke overfitting ka khatra badh jata hai, matlab ke model data points ko zyada closely fit kar leta hai lekin future data ke sath kamzor ho sakta hai. Isliye, polynomial regression mein degree ko sahi tarah se choose karna zaroori hai.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import operator

# Step 1: Create Dummy Data
np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + np.random.normal(-3, 3, 20)

# Reshaping for the model
x = x[:, np.newaxis]
y = y[:, np.newaxis]

# Step 2: Polynomial Transformation
degree = 4  # Degree of the polynomial
poly_features = PolynomialFeatures(degree=degree)
x_poly = poly_features.fit_transform(x)

# Step 3: Train Linear Regression Model
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

# Step 4: Plotting the results
plt.scatter(x, y, color='blue')
sorted_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x, y_poly_pred), key=sorted_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='magenta')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ---

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import operator

# %% [markdown]
# - Importing libraries
#     - Numpy
#     - pandas
#     - matplotlib
#     - polynomial features,linear regression
#     - Metrics

# %%
# Step 1: Create a dumy data
np.random.seed(0)
x = 2-3 * np.random.normal(0, 2 ,10)
y = x - 2 * (x ** 2) + np.random.normal(-3, 3, 10)

# %% [markdown]
# `np.random.seed(0)` ka matlab hai ke aapne random number generator ko ek seed value di hai, yani ke aapne specify kiya hai ke aap chahte hain ke har bar jab aap ye code run karenge, toh wahi random numbers generate honge. Iska faida ye hai ke agar aap seed value specify nahi karte toh har bar different random numbers generate hote hain, jiski wajah se code ka behavior har bar alag hota hai. Seed value set karke, aap ensure kar sakte hain ke har bar same random numbers generate ho, jisse aapke code ka reproducibility bana rahega.
#
# Ab aate hain aapke diye gaye code ki taraf. Ye code ek dataset generate kar raha hai jisme \(x\) aur \(y\) variables hain. Yeh dataset 10 points se milta hai.
#
# 1. `x = 2 - 3 * np.random.normal(0, 2, 10)`: Yahan, `np.random.normal(0, 2, 10)` ek normal distribution se random numbers generate kar raha hai jinka mean (average) 0 hai aur standard deviation 2 hai. Fir in numbers ko 3 se multiply karke 2 se subtract kar rahe hain. Isse \(x\) variable ki values generate hoti hain.
#
# 2. `y = x - 2 * (x ** 2) + np.random.normal(-3, 3, 10)`: Yahan, (x) ki values ka square le kar 2 se multiply kiya gaya hai, fir isse subtract kiya gaya hai. Iske baad, `np.random.normal(-3, 3, 10)` se generate kiye gaye random numbers ko \(y\) mein add kiya gaya hai. Isse \(y\) variable ki values generate hoti hain.
#
# Ye dataset ek non-linear relationship ko represent karta hai, jisme (y) (x) ke square ke sath linearly depend karta hai aur phir ek constant term se subtract hota hai. Random noise ko bhi add kiya gaya hai \(y\) mein. Is tarah ka data polynomial regression ko samajhne aur implement karne ke liye istemal hota hai.

# %%
# step 2 : Reshaping for the model
x = x[:,np.newaxis]
y = y[:,np.newaxis]

# %% [markdown]
# Certainly! Jab aap likhte hain `x = x[:, np.newaxis]` aur `y = y[:, np.newaxis]`, toh aap apne \(x\) aur \(y\) ko ek column vector mein convert kar rahe hain. Isse, aapke data ka format machine learning models ke sath match karega aur aap aasani se non-linear relationships ko model kar sakte hain.

# %%
# step 3 :Transformation to polynomial
Degree = 4
polynomialFeatures = PolynomialFeatures(degree=degree)
x_poly =poly_features.fit_transform(x)


# step 4: Train the linear regression model
model = LinearRegression()
model.fit(x_poly , y)
y_pred = model.predict(x_poly)

# %%
# Step 5: Plotting the results
plt.scatter(x,y , color ='Blue')
sorted_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_pred), key=sorted_axis)
x,y_pred = zip(*sorted_zip)
plt.plot(x,y_pred , color = 'Red' )
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
