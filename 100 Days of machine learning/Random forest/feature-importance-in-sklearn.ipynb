# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.iloc[:,1:]
y = df.iloc[:,-1]

# %%
y.shape
# Out:
# (303,)

# %%
sns.heatmap(X.iloc[5].values.reshape(28,28))

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
importance= rf.feature_importances_

# %%
rf.feature_importances_.shape
# Out:
# (13,)

# %%
# Feature Importance ko DataFrame mein convert karna
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
# Feature Importance ko print karna
print(feature_importance_df)
# Out:
#      Feature  Importance
# 12    target    0.554916
# 1         cp    0.072574
# 10        ca    0.072503
# 11      thal    0.066133
# 8    oldpeak    0.051573
# 6    thalach    0.051026
# 7      exang    0.037248
# 2   trestbps    0.026976
# 3       chol    0.025570
# 9      slope    0.017333
# 0        sex    0.013989
# 5    restecg    0.006677
# 4        fbs    0.003483

# %%
import matplotlib.pyplot as plt

# Visualization (Bar Plot)
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.title('Feature Importance in Heart Disease Prediction')
plt.show()

# %%
sns.heatmap(rf.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.heatmap(rf.feature_importances_)
#
# File c:\Users\zeesh\miniconda3\envs\tf_env\lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File c:\Users\zeesh\miniconda3\envs\tf_env\lib\site-packages\seaborn\matrix.py:115, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     112 # Validate the mask and convert to DataFrame
#     113 mask = _matrix_mask(data, mask)
# --> 115 plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     117 # Get good names for the rows and columns
#     118 xtickevery = 1
#
# File c:\Users\zeesh\miniconda3\envs\tf_env\lib\site-packages\numpy\ma\core.py:1933, in masked_where(condition, a, copy)
#    1931 (cshape, ashape) = (cond.shape, a.shape)
#    1932 if cshape and cshape != ashape:
# -> 1933     raise IndexError("Inconsistent shape between the condition and the input"
#    1934                      " (got %s and %s)" % (cshape, ashape))
#    1935 if hasattr(a, '_mask'):
#    1936     cond = mask_or(cond, a._mask)
#
# IndexError: Inconsistent shape between the condition and the input (got (13, 1) and (13,))
